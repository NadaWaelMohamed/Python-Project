# %% [markdown]
# <a href="https://colab.research.google.com/github/NadaWaelMohamed/Python-Project/blob/main/SelectedTopics_ProjectV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#a.	For Each .csv file create a data frame
result = pd.read_excel('Canada_Hosp2_COVID_InpatientData.xlsx','Data-at-admission')
result2 = pd.read_excel('Canada_Hosp2_COVID_InpatientData.xlsx','Hospital-length-of-stay')
result3 = pd.read_excel('Canada_Hosp2_COVID_InpatientData.xlsx','Days-breakdown')

# %%
df = pd.DataFrame(result)
df2 = pd.DataFrame(result2)
df3 = pd.DataFrame(result3)

# %%
#b.	Merge all data frames one data frame ( don’t merge all columns select valuable based on your opinion Min=20 Att)
dfs = [df.iloc[:, 0:20], df2.iloc[:, 10:30], df3.iloc[0:50,:]]
resultconc = pd.concat(dfs)
resultconc
# Out:
#       id reason_for_admission   age     sex ethnicity ethnicity_other  height  \
# 0    1.0      COVID positive   49.0  Female      "[]"             NaN     NaN
# 1    2.0  referred for sepsis  78.0    Male      "[]"             NaN     NaN
# 2    3.0                  NaN  92.0  Female      "[]"             NaN     NaN
# 3    4.0           Pneumonia   96.0    Male      "[]"             NaN     NaN
# 4    5.0       Abdominal pain  63.0  Female      "[]"             NaN     NaN
# ..   ...                  ...   ...     ...       ...             ...     ...
# 45  46.0                  NaN   NaN     NaN       NaN             NaN     NaN
# 46  47.0                  NaN   NaN     NaN       NaN             NaN     NaN
# 47  48.0                  NaN   NaN     NaN       NaN             NaN     NaN
# 48  49.0                  NaN   NaN     NaN       NaN             NaN     NaN
# 49  50.0                  NaN   NaN     NaN       NaN             NaN     NaN
#
# ...

# %%
#c.	Display number of Nulls or Missing Values in Each Column
df.isnull().sum() #Admission
# Out:
# id                                    0
# reason_for_admission                  2
# age                                   0
# sex                                   3
# ethnicity                             0
# ethnicity_other                     143
# height                              176
# weight                              170
# comorbidities                         0
# comorbidities_other                  84
# received_covid_vaccine               14
# covid_vaccine                       200
# medications                           0
# smoking_history                       8
# year_they_quit                      182
# previous_er_visit_within_14_days      8
# admission_disposition                 8
# systolic_blood_pressure               8
# diastolic_blood_pressure              9
# heart_rate                           27
# respiratory_rate                     23
# oxygen_saturation                    11
# temperature                          14
# ...

# %%
df2.isnull().sum()
# Out:
# id                                                    0
# parent_id                                             0
# did_the_patient_expire_in_hospital                    6
# reason_for_death                                    170
# days_in_hospital_prior_to_expiration                170
# hospital_length_of_stay                               0
# icu_length_of_stay                                  144
# days_in_hospital_prior_to_icu_admission             180
# time_on_mechanical_ventilation                      165
# days_in_hospital_prior_to_mechanical_ventilation    178
# days_to_first_covid19_test_negative                 181
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# id                            0
# parent_id                     0
# day                           0
# systolic_blood_pressure     494
# diastolic_blood_pressure    494
#                            ...
# head_ct                     461
# head_ct_findings              0
# antimicrobial               437
# anticoagulation             433
# steroid                     440
# Length: 70, dtype: int64

# %%
#d.	IF Numeric Handle Missing Value (AVG, MAX, MIN)

# %%
#max
dfmax = df.select_dtypes(include=np.number).fillna(df.max())
dfmax
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   181.0   106.0          2020.0                    132.0
# 1      2   78   181.0   106.0          2020.0                    108.0
# 2      3   92   181.0   106.0          2001.0                    131.0
# 3      4   96   181.0   106.0          1990.0                    135.0
# 4      5   63   181.0   106.0          2020.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   181.0   106.0          2020.0                    101.0
# 197  198   65   181.0   106.0          2020.0                    104.0
# ...

# %%
#avg
avg=df.select_dtypes(include=np.number).fillna(df.mean())
avg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#       id  age  height     weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49  167.16  78.287097     1999.631579                    132.0
# 1      2   78  167.16  78.287097     1999.631579                    108.0
# 2      3   92  167.16  78.287097     2001.000000                    131.0
# 3      4   96  167.16  78.287097     1990.000000                    135.0
# 4      5   63  167.16  78.287097     1999.631579                    133.0
# ..   ...  ...     ...        ...             ...                      ...
# 196  197   32  167.16  78.287097     1999.631579                    101.0
# 197  198   65  167.16  78.287097     1999.631579                    104.0
# ...

# %%
#min
min = df.select_dtypes(include=np.number).fillna(df.min())
min
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   150.0    48.0          1980.0                    132.0
# 1      2   78   150.0    48.0          1980.0                    108.0
# 2      3   92   150.0    48.0          2001.0                    131.0
# 3      4   96   150.0    48.0          1990.0                    135.0
# 4      5   63   150.0    48.0          1980.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   150.0    48.0          1980.0                    101.0
# 197  198   65   150.0    48.0          1980.0                    104.0
# ...

# %%
#e.	Save this data frame to another CSV called (DS_Prepared)
resultconc.to_csv('DS_Prepared.csv', index=False)

# %%
#f.Based on your data construct at least 3 more attributes and add them to your data set ( add , subtract , multiply, concatenate)
#add
AddColumn = dfmax["height"] + dfmax["weight"]
dfmax["Sum"] = AddColumn
dfmax
# Out:
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   181.0   106.0          2020.0                    132.0
# 1      2   78   181.0   106.0          2020.0                    108.0
# 2      3   92   181.0   106.0          2001.0                    131.0
# 3      4   96   181.0   106.0          1990.0                    135.0
# 4      5   63   181.0   106.0          2020.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   181.0   106.0          2020.0                    101.0
# 197  198   65   181.0   106.0          2020.0                    104.0
# 198  199   60   181.0   106.0          2020.0                    150.0
# 199  200   63   181.0   106.0          2020.0                    157.0
# 200  201   81   181.0   106.0          2020.0                    106.0
#
#      diastolic_blood_pressure  heart_rate  respiratory_rate  \
# ...

# %%
#Subtract
SubtractColumn = dfmax["height"] - dfmax["weight"]
dfmax["Subtract"] = SubtractColumn
dfmax
# Out:
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   181.0   106.0          2020.0                    132.0
# 1      2   78   181.0   106.0          2020.0                    108.0
# 2      3   92   181.0   106.0          2001.0                    131.0
# 3      4   96   181.0   106.0          1990.0                    135.0
# 4      5   63   181.0   106.0          2020.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   181.0   106.0          2020.0                    101.0
# 197  198   65   181.0   106.0          2020.0                    104.0
# 198  199   60   181.0   106.0          2020.0                    150.0
# 199  200   63   181.0   106.0          2020.0                    157.0
# 200  201   81   181.0   106.0          2020.0                    106.0
#
#      diastolic_blood_pressure  heart_rate  respiratory_rate  \
# ...

# %%
#Multiply
MultiplyColumn = dfmax["height"] * dfmax["weight"]
dfmax["Multiply"] = MultiplyColumn
dfmax
# Out:
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   181.0   106.0          2020.0                    132.0
# 1      2   78   181.0   106.0          2020.0                    108.0
# 2      3   92   181.0   106.0          2001.0                    131.0
# 3      4   96   181.0   106.0          1990.0                    135.0
# 4      5   63   181.0   106.0          2020.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   181.0   106.0          2020.0                    101.0
# 197  198   65   181.0   106.0          2020.0                    104.0
# 198  199   60   181.0   106.0          2020.0                    150.0
# 199  200   63   181.0   106.0          2020.0                    157.0
# 200  201   81   181.0   106.0          2020.0                    106.0
#
#      diastolic_blood_pressure  heart_rate  respiratory_rate  \
# ...

# %%
#Concatenate
Concat = dfmax['weight'].astype(str) + "-" + dfmax['height'].astype(str)
dfmax["Concatination"] = Concat
dfmax
# Out:
#       id  age  height  weight  year_they_quit  systolic_blood_pressure  \
# 0      1   49   181.0   106.0          2020.0                    132.0
# 1      2   78   181.0   106.0          2020.0                    108.0
# 2      3   92   181.0   106.0          2001.0                    131.0
# 3      4   96   181.0   106.0          1990.0                    135.0
# 4      5   63   181.0   106.0          2020.0                    133.0
# ..   ...  ...     ...     ...             ...                      ...
# 196  197   32   181.0   106.0          2020.0                    101.0
# 197  198   65   181.0   106.0          2020.0                    104.0
# 198  199   60   181.0   106.0          2020.0                    150.0
# 199  200   63   181.0   106.0          2020.0                    157.0
# 200  201   81   181.0   106.0          2020.0                    106.0
#
#      diastolic_blood_pressure  heart_rate  respiratory_rate  \
# ...

# %% [markdown]
# # **Analyse** your Data Set

# %%
#i.	USING PRINT Display Number of Rows 
print('Row count (Data-at-admission):', len(df))
#or
print('Row count (Data-at-admission):', df.shape[0])
print('Row count (Hospital-length-of-stay):', len(df2))
print('Row count (Days-breakdown):', len(df3))
# Out:
# Row count (Data-at-admission): 201
# Row count (Data-at-admission): 201
# Row count (Hospital-length-of-stay): 199
# Row count (Days-breakdown): 1574

# %%
#ii.Number of Columns
print("Number of columns (Data-at-admission):", df.shape[1])
print("Number of columns (Hospital-length-of-stay):", df2.shape[1])
print("Number of columns (Days-breakdown):", df3.shape[1])
# Out:
# Number of columns (Data-at-admission): 55
# Number of columns (Hospital-length-of-stay): 11
# Number of columns (Days-breakdown): 70

# %%
#ii.USING PRINT Display Column Names
for col in df.columns:
    print(col)
# Out:
# id
# reason_for_admission
# age
# sex
# ethnicity
# ethnicity_other
# height
# weight
# comorbidities
# comorbidities_other
# received_covid_vaccine
# covid_vaccine
# medications
# smoking_history
# year_they_quit
# previous_er_visit_within_14_days
# admission_disposition
# systolic_blood_pressure
# diastolic_blood_pressure
# heart_rate
# respiratory_rate
# oxygen_saturation
# temperature
# motor
# verbal
# eye
# intubated
# wbc
# rbc
# hemoglobin
# hematocrit
# mcv
# mch
# mchc
# rdw
# platelet_count
# aptt_aptr
# pt
# alt
# ast
# serum_creatinine
# sodium
# potassium
# total_serum_bilirubin
# lactate
# pao2
# pao2_fio2
# ph
# high_senstivity_cardiac_troponin
# esr
# inr
# ferritin
# d_dimer
# crp
# hs_crp

# %%
for col in df2.columns:
    print(col)
# Out:
# id
# parent_id
# did_the_patient_expire_in_hospital
# reason_for_death
# days_in_hospital_prior_to_expiration
# hospital_length_of_stay
# icu_length_of_stay
# days_in_hospital_prior_to_icu_admission
# time_on_mechanical_ventilation
# days_in_hospital_prior_to_mechanical_ventilation
# days_to_first_covid19_test_negative

# %%
for col in df3.columns:
    print(col)
# Out:
# id
# parent_id
# did_the_patient_expire_in_hospital
# reason_for_death
# days_in_hospital_prior_to_expiration
# hospital_length_of_stay
# icu_length_of_stay
# days_in_hospital_prior_to_icu_admission
# time_on_mechanical_ventilation
# days_in_hospital_prior_to_mechanical_ventilation
# days_to_first_covid19_test_negative

# %%
#iii.USING PRINT Display Data Frame Size
print("Sheet 1" , df.shape)
print("Sheet 2" ,df3.shape)
print("Sheet 3" ,df2.shape)
# Out:
# Sheet 1 (201, 55)
# Sheet 2 (1574, 70)
# Sheet 3 (199, 11)

# %%
#iv.USING PRINT Display Data Frame First Little Records
df[0:4]
# Out:
#    id reason_for_admission  age     sex ethnicity ethnicity_other  height  \
# 0   1      COVID positive    49  Female      "[]"             NaN     NaN
# 1   2  referred for sepsis   78    Male      "[]"             NaN     NaN
# 2   3                  NaN   92  Female      "[]"             NaN     NaN
# 3   4           Pneumonia    96    Male      "[]"             NaN     NaN
#
#    weight                                      comorbidities  \
# 0     NaN                                               "[]"
# 1     NaN                                               "[]"
# 2     NaN  "[\"Chronic cardiac disease (not hypertension)...
# 3     NaN  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  ... pao2 pao2_fio2  \
# 0                                                NaN  ...  NaN       NaN
# 1                                                NaN  ...  NaN       NaN
# ...

# %%
#v.USING PRINT Display Data Frame First Little Records ( Display all columns )
df.iloc[0:4,:]
# Out:
#    id reason_for_admission  age     sex ethnicity ethnicity_other  height  \
# 0   1      COVID positive    49  Female      "[]"             NaN     NaN
# 1   2  referred for sepsis   78    Male      "[]"             NaN     NaN
# 2   3                  NaN   92  Female      "[]"             NaN     NaN
# 3   4           Pneumonia    96    Male      "[]"             NaN     NaN
#
#    weight                                      comorbidities  \
# 0     NaN                                               "[]"
# 1     NaN                                               "[]"
# 2     NaN  "[\"Chronic cardiac disease (not hypertension)...
# 3     NaN  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  ... pao2 pao2_fio2  \
# 0                                                NaN  ...  NaN       NaN
# 1                                                NaN  ...  NaN       NaN
# ...

# %%
#vi.USING PRINT Display Data Frame NUMBER OF ELEMENTS
print("Sheet 1 number of elements" , df.size)
print("Sheet 2 number of elements" , df3.size)
print("Sheet 3 number of elements" , df2.size)
# Out:
# Sheet 1 number of elements 11055
# Sheet 2 number of elements 110180
# Sheet 3 number of elements 2189

# %%
#viii.Select at least 2 numeric attribute and try to analyze its data 
#3ayz meen 22l fehom homa el etnaann 
#1.	Min, 
#2.	Max , 
#3.	AVG Value 
print("Min between parent id and days_in_hospital_prior_to_icu_admission ", df2[['parent_id', 'days_in_hospital_prior_to_icu_admission']].min().min())
print("Max between heart rate and day", df3[['heart_rate', 'day']].max().max())
print("Avg between heart rate and day", df[['height', 'weight']].mean().mean())

#meen min aw max f kol column
print("")
print("Min between parent id and days_in_hospital_prior_to_icu_admission ", df2[['parent_id', 'days_in_hospital_prior_to_icu_admission']].min())
print("Max between heart rate and day", df3[['heart_rate', 'day']].max())
print("Avg between heart rate and day", df[['height', 'weight']].mean())
# Out:
# Min between parent id and days_in_hospital_prior_to_icu_admission  1.0
# Max between heart rate and day 147.0
# Avg between heart rate and day 122.72354838709677
#
# Min between parent id and days_in_hospital_prior_to_icu_admission  parent_id                                  1.0
# days_in_hospital_prior_to_icu_admission    1.0
# dtype: float64
# Max between heart rate and day heart_rate    147.0
# day            14.0
# dtype: float64
# Avg between heart rate and day height    167.160000
# weight     78.287097
# dtype: float64

# %%
#ix.	Construct another data frame based on vi as follows
#Col1     Col2
#			Min
#			Max
#			AVG
Sheet1 = df.size
Sheet2 = df2.size
Sheet3 = df3.size


dfx = pd.DataFrame(columns='Col1 Col2 Col3'.split())
dfx.loc['DataFrame'] = pd.Series({'Col1':Sheet1, 'Col2':Sheet3, 'Col3':Sheet2})
print(dfx)
print("Min", dfx.min().min())
print("Max", dfx.max().max())
print("AVG", dfx.mean().mean())
# Out:
#             Col1    Col2  Col3
# DataFrame  11055  110180  2189
# Min 2189
# Max 110180
# AVG 41141.333333333336

# %%
#xi.For Column AGE display a summary statistics that describes this column
df['age'].describe()
# Out:
# count    201.000000
# mean      67.054726
# std       19.667536
# min       18.000000
# 25%       56.000000
# 50%       69.000000
# 75%       83.000000
# max       98.000000
# Name: age, dtype: float64

# %%
#xii.	Group Your Data By ‘SEX’ Column then Display the mean values of other Columns 
df.groupby(["sex"]).mean()
# Out:
#                 id       age      height     weight  year_they_quit  \
# sex
# Female   98.122449  68.22449  161.727273  76.415385     1999.250000
# Male    104.830000  65.87000  171.428571  79.638889     2000.714286
#
#         systolic_blood_pressure  diastolic_blood_pressure  heart_rate  \
# sex
# Female               130.840426                 73.553191   91.423529
# Male                 133.635417                 75.705263   89.941860
#
#         respiratory_rate  oxygen_saturation  ...  pao2  pao2_fio2        ph  \
# sex                                          ...
# Female         21.056818          93.527473  ...  84.0        NaN  7.314390
# Male           21.195402          93.312500  ...  74.0        NaN  7.376977
#
#         high_senstivity_cardiac_troponin   esr       inr    ferritin  \
# sex
# Female                              35.5   NaN  1.284634  361.083333
# Male                                30.5  26.5  1.357609  879.454545
#
# ...

# %%
#xiii.Determine How many rows are F or M
df["sex"].value_counts()
# Out:
# Male      100
# Female     98
# Name: sex, dtype: int64

# %%
#xiv.	CONVERT YOUR .CSV TO .TXT FILE
np.savetxt(r'E:\Semester 8\Selected Topics\Section\SelectedProject', df.values, fmt='%d')

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pointer = open("E:\Semester 8\Selected Topics\Section\SelectedProject" , "r")
text = pointer.read()
pointer.close()
print(text)
result = word_tokenize(text)
#return frequency of words
freq= nltk.FreqDist(result)
#first three words
print(freq.most_common(3))
# Out:
# 11055 110180 2189
#
# [('11055', 1), ('110180', 1), ('2189', 1)]

# %% [markdown]
# ## **Visualization**

# %%
df.plot.box(color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df2.plot.scatter('parent_id','days_in_hospital_prior_to_icu_admission', figsize=(16,4), color='red')

# %%
df3['systolic_blood_pressure'].plot.bar(color='blue')

# %%
df2.plot.bar(color = 'red')

# %%
df3['systolic_blood_pressure'].plot.hist(color='blue')

# %%
import seaborn as sb

# %%
plt.subplots()        
sb.heatmap(df.corr(),cmap='coolwarm')
